# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('results2.pkl', 'rb') as inp:
    results = pickle.load(inp)
    
for snr_trh in [10, 20, 30, 40, 50, 60]:
    for dist_trh in [1.5, 2.0, 2.5, 3.0, 3.5, 4.0]:
        iteration = "snr_trh:" + str(snr_trh) + " dist_trh:" + str(dist_trh)
        for inverse_method in ["weighted a ",
                              "weighted b ",
                              "lstsq a ",
                              "lstsq b "]:
            title = inverse_method + iteration
            values = results[title]

            plt.hist(values, bins = 50,
                    alpha=0.5,
                    facecolor="C1",
                    edgecolor="black",
                    linewidth=1
                    )
            plt.title(title)
            plt.xlabel("Value - mean(initial_value)")
            plt.ylabel("Counts")
            # plt.xlim(-0.005, 0)
            # plt.ylim(0, 80)
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j4/gh4kt35s7nq38zc3s9cx7td40000gn/T/ipykernel_41807/411126035.py in <module>
#      10                               "lstsq b "]:
#      11             title = inverse_method + iteration
# ---> 12             values = results[title]
#      13
#      14             plt.hist(values, bins = 50,
#
# KeyError: 'weighted a snr_trh:40 dist_trh:2.5'

# %%
with open("/Users/localadmin/Dropbox/GitHub/ocloc/tutorials/bootstrap_a_minuus_mean_a_same_iteration.pkl", 'rb') as inp:
    results = pickle.load(inp)
    
for snr_trh in [10, 20, 30, 40, 50, 60]:
    for dist_trh in [1.5, 2.0, 2.5, 3.0, 3.5, 4.0]:
        iteration = "snr_trh:" + str(snr_trh) + " dist_trh:" + str(dist_trh)
        for inverse_method in ["weighted a ",
                              #"weighted b ",
                              "lstsq a ",
                              #"lstsq b "
                              ]:
            title = inverse_method + iteration
            values = results[title]
            plt.hist(data, bins=np.arange(min(data),
                                          max(data) + binwidth, binwidth))
            
            plt.hist(values, bins = 50,
                    alpha=0.5,
                    facecolor="C1",
                    edgecolor="black",
                    linewidth=1
                    )
            plt.title(title)
            plt.xlabel("Value - mean(initial_value)")
            plt.xlim(-0.01, 0.01)
            plt.ylabel("Counts")
            # plt.xlim(-0.005, 0)
            # plt.ylim(0, 80)
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j4/gh4kt35s7nq38zc3s9cx7td40000gn/T/ipykernel_41807/2516567225.py in <module>
#      11                               ]:
#      12             title = inverse_method + iteration
# ---> 13             values = results[title]
#      14
#      15             plt.hist(values, bins = 50,
#
# KeyError: 'weighted a snr_trh:20 dist_trh:2.0'
